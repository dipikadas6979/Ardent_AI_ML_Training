# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# variables, Data types, Operators

# %%
# calculate area of a triangle

h=20
b=10
area= 1/2 * b * h
print(area)
# Out:
# 100.0

# %% [markdown]
# understanding f- string

# %%
# calculate area of a triangle

h=20
b=10

print("The area is:" ,1/2 * b * h)
print(f"The area is:{1/2 * b* h}")
# Out:
# The area is: 100.0
# The area is:100.0

# %% [markdown]
# lists & indexing

# %%
marks =[70, 85, 90, 60]
print(marks)
# Out:
# [70, 85, 90, 60]

# %% [markdown]
# lists & indexing

# %%
marks = [70, 85, 90, 60]
print(marks)
print(marks[0]) # first element
print(marks[-1]) # last element
# Out:
# [70, 85, 90, 60]
# 70
# 60

# %% [markdown]
# loops: for, while

# %%
# print 1-10 using for loop
for i in range(10,3,-2):
  print(i)

 # print even number from (1-11,2):
for i in range(10,3,-2):
  print(i)
   # print odd number from 3-21
for i in range(10,3,-2):
  print(i)
   # print reverse number from 10-1
  for i in range(10,3,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 10
# 8
# 6
# 4
# 10
# 10
# 8
# 6
# 4
# 8
# 10
# 8
# 6
# 4
# 6
# 10
# 8
# 6
# 4
# 4
# 10
# 8
# 6
# 4

# %% [markdown]
# string & it method

# %%
name ="Ardent"

print(name)
print(name.upper())
print(name.lower())
print(name.index("A"))
# Out:
# Ardent
# ARDENT
# ardent
# 0

# %% [markdown]
# **Function**
# userdefined function as a developer what you are making in build function

# %%
# function to calculate average
def avg(phy, che, math):
  return (phy+che+math)/3

print(avg(50,60,80))
# for perfection: u should know function definition,calling function, parameter, arguments
# Out:
# 63.333333333333336
